# %%
import numpy as np
import keras
from keras import backend as K
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense, Flatten
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import *
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-270719bbcd9b> in <module>
#      11 from keras.layers.convolutional import *
#      12 from matplotlib import pyplot as plt
# ---> 13 from sklearn.metrics import confusion_matrix
#      14 import itertools
#      15 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
train_path = 'C:/Users/Nuxx/Desktop/X/Datasets2/PetImages/Train'
valid_path = 'C:/Users/Nuxx/Desktop/X/Datasets2/PetImages/Valid'
test_path = 'C:/Users/Nuxx/Desktop/X/Datasets2/PetImages/Test'

# %%
train_batches = ImageDataGenerator().flow_from_directory(train_path, target_size=(224,224), classes=['dog','cat'], batch_size=20)
valid_batches = ImageDataGenerator().flow_from_directory(valid_path, target_size=(224,224), classes=['dog','cat'], batch_size=10)
test_batches = ImageDataGenerator().flow_from_directory(test_path, target_size=(224,224), classes=['dog','cat'], batch_size=10)

# %%
def plots(ims, figsize=(12,6), rows=2, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if(ims.shape[-1] != 3):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows +1
    for i in range(len(ims)):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i], interpolation=None if interp else 'none')

# %%
imgs, labels = next(train_batches)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f59bc0e91187> in <module>
# ----> 1 imgs, labels = next(train_batches)
#
# NameError: name 'train_batches' is not defined

# %%
plots(imgs, titles=labels)

# %%
model = Sequential()


#Conv1 layer
model.add(Conv2D(64, (3,3), input_shape =(224,224,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

#Conv2 layer
model.add(Conv2D(64, (3,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())    #Flatten 3D feature maps to column vector(x,1)

#FC layer
model.add(Dense(64))
model.add(Activation("relu"))

#Sigmoid/Softmax layer
model.add(Dense(2))
model.add(Activation("softmax"))

# %%
model.compile(loss="binary_crossentropy",
                optimizer="adam",
                metrics=['accuracy'])

# %%
model.fit_generator(train_batches, validation_data=valid_batches, epochs=5, steps_per_epoch=4, validation_steps=4, verbose=2)
# Out:
# Epoch 1/5
#  - 46s - loss: 8.3143 - acc: 0.4625 - val_loss: 7.2136 - val_acc: 0.5500
# Epoch 2/5
#  - 39s - loss: 8.6163 - acc: 0.4625 - val_loss: 9.2174 - val_acc: 0.4250
# Epoch 3/5
#  - 37s - loss: 6.8129 - acc: 0.5750 - val_loss: 6.4121 - val_acc: 0.6000
# Epoch 4/5
#  - 37s - loss: 8.4159 - acc: 0.4750 - val_loss: 9.2174 - val_acc: 0.4250
# Epoch 5/5
#  - 37s - loss: 7.4140 - acc: 0.5375 - val_loss: 5.6106 - val_acc: 0.6500

# %%
test_imgs, test_labels = next(test_batches)
plots(test_imgs, titles=test_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fc603103281e> in <module>
# ----> 1 test_imgs, test_labels = next(test_batches)
#       2 plots(test_imgs, titles=test_labels)
#
# NameError: name 'test_batches' is not defined

# %%
test_imgs, test_labels = next(test_batches)
plots(test_imgs, titles=test_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-9daf3523bda4> in <module>
# ----> 1 test_imgs, test_labels = next(test_batches)
#
# NameError: name 'test_batches' is not defined

# %%
# Showing array of classes 

test_labels = test_labels[:,0]
test_labels
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-931a7ffb0df4> in <module>
#       1 # Showing array of classes
#       2
# ----> 3 test_labels = test_labels[:,0]
#       4 test_labels
#
# NameError: name 'test_labels' is not defined

# %%
predictions = model.predict_generator(test_batches, steps=1, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-4ef9a6a4a90e> in <module>
# ----> 1 predictions = model.predict_generator(test_batches, steps=1, verbose=0)
#
# NameError: name 'model' is not defined

# %%
predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fd2951b82103> in <module>
# ----> 1 predictions
#
# NameError: name 'predictions' is not defined

# %%
cm = confusion_matrix(test_labels, predictions[:,0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d1fd780c439d> in <module>
# ----> 1 cm = confusion_matrix(test_labels, predictions[:,0])
#
# NameError: name 'confusion_matrix' is not defined

# %%
def plot_confusion_matrix(cm, classes, normalize = False, title ='Confusion Matrix', cmap=plt.cm.Blues):
    
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting 'normalize=true'.
    """
    
    plt.imshow(cm, inerpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    ticks_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    
    
    thresh = cm.max() / 2.
    for i, j in inertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                horizontalaligment='center'
                color='white' if cm[i, j] > thresh else 'black')
        
    plt.tight_layout()
    plt.ylabel('true label')
    plt.xlabel('Predicted label')

# %%
cm_plot_labels = ['cat','dog']
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix')
